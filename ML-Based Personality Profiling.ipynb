# %% [markdown]
# # ML-Based Personality Profiling

# %% [markdown]
# # 1. Data Inspection

# %% [markdown]
# ## Dataset

# %%
import pandas as pd
train_df = pd.read_csv(r'C:\Users\moham\OneDrive\Documents\Gradtwin\project.csv')
train_df
# Out:
#        Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0        Male   25         4            7                  2              5
# 1      Female   52         4            2                  5              5
# 2      Female   22         4            6                  7              6
# 3      Female   40         5            2                  1              4
# 4        Male   42         7            1                  5              6
# ...       ...  ...       ...          ...                ...            ...
# 49995  Female   42         2            2                  1              5
# 49996    Male   55         7            3                  4              2
# 49997  Female   34         7            3                  4              6
# 49998  Female   57         7            2                  3              1
# 49999  Female   40         7            7                  7              2
#
# ...

# %% [markdown]
# # ML based personality profiling
# * Age
#     * It describe from the age of the gender
#     * The nominal range from 0 to 100
#     * The datatype of the column is integer(int)
# * Openess
#     * It Reflects imagination and a preference for novelty and variety.
#     * The nominal range from 0 to 10
#     * The datatytpe of the column is integer(int).
# * Neuroticism
#     * It refers to a person's tendency to experience negative emotions such as anxiety, anger, envy, guilt, and depression.
#     * The nominal range from 0 to 10
#     * The datatytpe of the column is integer(int).
# * Conscientiousness
#     * Degree to which a person is organized, responsible, and hardworking.
#     * The nominal range from 0 to 10
#     * The datatytpe of the column is integer(int).
# *  Agreeableness
#     * Degree to which a person is cooperative, kind, and compassionate
#     * The nominal range from 0 to 10
#     * The datatytpe of the column is integer(int).
# * 	Extraversion
#     * Degree to which a person is outgoing, energetic, and sociable.
#     *  The nominal range from 0 to 10
#     * The datatytpe of the column is integer(int).
# * Total_Trait_Score
#     * It describe from the total value of characters
#     * The nominal range from 0 to 100
#     * The datatype of the column is integer(int)
# * Dominant_Trait
#     * It describe from judge the character
#     * There is no nominal range of the colummn
#     * The datatype of the column is string(str)
# * Gender Code
#     * It describe from the category of gender like '0' for Female and '1' for Male
#     * The nominal range is 0 to 1
#     * The datatype of the column is integer(int)
# * Age group
#     * It describe based on the stage of the gender
#     * There is no nominal range of the column
#     * The datatype of the column is string(str)
# * Class
#     * It describe from the character based on the categories
#     * There is no nominal range of the column
#     * The datatype of the column is string(str)

# %% [markdown]
# ## Display the first 5 rows in the dataset

# %%
display(train_df.head(5))
# Out:
#    Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0    Male   25         4            7                  2              5
# 1  Female   52         4            2                  5              5
# 2  Female   22         4            6                  7              6
# 3  Female   40         5            2                  1              4
# 4    Male   42         7            1                  5              6
#
#    extraversion  Total_Trait_Score     Dominant_Trait  Trait_Balance  \
# 0             2                 20        neuroticism       1.897367
# 1             6                 22       extraversion       1.356466
# 2             1                 24  conscientiousness       2.135416
# 3             6                 18       extraversion       1.854724
# 4             2                 21           openness       2.315167
#
#      Age_Group  Gender_Code  Openness_Conscientiousness_Ratio  Risk_Index  \
# ...

# %% [markdown]
# ## Display the last 5 rows of the dataset

# %%
display(train_df.tail(5))
# Out:
#        Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 49995  Female   42         2            2                  1              5
# 49996    Male   55         7            3                  4              2
# 49997  Female   34         7            3                  4              6
# 49998  Female   57         7            2                  3              1
# 49999  Female   40         7            7                  7              2
#
#        extraversion  Total_Trait_Score Dominant_Trait  Trait_Balance  \
# 49995             5                 15  agreeableness       1.673320
# 49996             3                 19       openness       1.720465
# 49997             2                 22       openness       1.854724
# 49998             7                 20       openness       2.529822
# 49999             7                 30       openness       2.000000
#
#       Age_Group  Gender_Code  Openness_Conscientiousness_Ratio  Risk_Index  \
# ...

# %% [markdown]
# # Finding the shape of the dataset

# %%
print('The shape of my dataset is:',train_df.shape)
# Out:
# The shape of my dataset is: (50000, 15)

# %% [markdown]
# # What are all the column present in the dataset to find

# %%
print('The column present in the dataset is:',train_df.columns)
# Out:
# The column present in the dataset is: Index(['Gender', 'Age', 'openness', 'neuroticism', 'conscientiousness',
#        'agreeableness', 'extraversion', 'Total_Trait_Score', 'Dominant_Trait',
#        'Trait_Balance', 'Age_Group', 'Gender_Code',
#        'Openness_Conscientiousness_Ratio', 'Risk_Index', 'Class'],
#       dtype='object')

# %% [markdown]
# # Finding the datatype of the dataset

# %%
display(train_df.dtypes)
# Out:
# Gender                               object
# Age                                   int64
# openness                              int64
# neuroticism                           int64
# conscientiousness                     int64
# agreeableness                         int64
# extraversion                          int64
# Total_Trait_Score                     int64
# Dominant_Trait                       object
# Trait_Balance                       float64
# Age_Group                            object
# Gender_Code                         float64
# Openness_Conscientiousness_Ratio    float64
# Risk_Index                          float64
# Class                                object
# dtype: object

# %% [markdown]
# # Summary of nulls and datatypes

# %%
display(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Gender                            50000 non-null  object
#  1   Age                               50000 non-null  int64
#  2   openness                          50000 non-null  int64
#  3   neuroticism                       50000 non-null  int64
#  4   conscientiousness                 50000 non-null  int64
#  5   agreeableness                     50000 non-null  int64
#  6   extraversion                      50000 non-null  int64
#  7   Total_Trait_Score                 50000 non-null  int64
#  8   Dominant_Trait                    50000 non-null  object
#  9   Trait_Balance                     50000 non-null  float64
#  10  Age_Group                         50000 non-null  object
# ...

# %%
display(train_df.value_counts())
# Out:
# Gender  Age  openness  neuroticism  conscientiousness  agreeableness  extraversion  Total_Trait_Score  Dominant_Trait     Trait_Balance  Age_Group    Gender_Code  Openness_Conscientiousness_Ratio  Risk_Index  Class
# Female  44   3         7            5                  6              7             28                 neuroticism        1.496663       Mid-age      0.0          0.600000                          3.4         At 44 years old, this female individual shows a dominant trait of neuroticism.          3
#         48   1         4            3                  2              4             14                 neuroticism        1.166190       Mid-age      0.0          0.333333                          1.9         At 48 years old, this female individual shows a dominant trait of neuroticism.          3
# ...

# %% [markdown]
# # Statistics summary of the numerical column

# %%
display(train_df.describe())
# Out:
#                 Age      openness   neuroticism  conscientiousness  \
# count  50000.000000  50000.000000  50000.000000       50000.000000
# mean      38.092820      3.996320      3.989220           3.992120
# std       12.401264      1.999967      1.999696           1.994527
# min       17.000000      1.000000      1.000000           1.000000
# 25%       27.000000      2.000000      2.000000           2.000000
# 50%       38.000000      4.000000      4.000000           4.000000
# 75%       49.000000      6.000000      6.000000           6.000000
# max       59.000000      7.000000      7.000000           7.000000
#
#        agreeableness  extraversion  Total_Trait_Score  Trait_Balance  \
# count   50000.000000  50000.000000       50000.000000   50000.000000
# mean        4.005120      3.992760          19.975540       1.725135
# std         1.999813      2.007084           4.467346       0.475896
# min         1.000000      1.000000           5.000000       0.000000
# ...

# %% [markdown]
# # Statistics of the categorical column

# %%
display(train_df.describe(include=object))
# Out:
#        Gender Dominant_Trait Age_Group  \
# count   50000          50000     50000
# unique      2              5         5
# top      Male       openness   Mid-age
# freq    25053          13786     17665
#
#                                                     Class
# count                                               50000
# unique                                                430
# top     At 33 years old, this female individual shows ...
# freq                                                  184

# %% [markdown]
# # To check whether there is null values in the columns

# %%
print(train_df.isnull().values.any())
# Out:
# False

# %% [markdown]
# # To check null values for the each column

# %%
display(train_df.isnull().sum())
# Out:
# Gender                              0
# Age                                 0
# openness                            0
# neuroticism                         0
# conscientiousness                   0
# agreeableness                       0
# extraversion                        0
# Total_Trait_Score                   0
# Dominant_Trait                      0
# Trait_Balance                       0
# Age_Group                           0
# Gender_Code                         0
# Openness_Conscientiousness_Ratio    0
# Risk_Index                          0
# Class                               0
# dtype: int64

# %% [markdown]
# # Remove leading/trailing spaces, replace spaces with underscores, convert to lowercase

# %%
train_df.columns.str.strip().str.lower()
# Out:
# Index(['gender', 'age', 'openness', 'neuroticism', 'conscientiousness',
#        'agreeableness', 'extraversion', 'total_trait_score', 'dominant_trait',
#        'trait_balance', 'age_group', 'gender_code',
#        'openness_conscientiousness_ratio', 'risk_index', 'class'],
#       dtype='object')

# %%
print('The length of the dataset is:',len(train_df))
# Out:
# The length of the dataset is: 50000

# %% [markdown]
# # Finding the memory usage of the dataset

# %%
display(train_df.memory_usage())
# Out:
# Index                                  132
# Gender                              400000
# Age                                 400000
# openness                            400000
# neuroticism                         400000
# conscientiousness                   400000
# agreeableness                       400000
# extraversion                        400000
# Total_Trait_Score                   400000
# Dominant_Trait                      400000
# Trait_Balance                       400000
# Age_Group                           400000
# Gender_Code                         400000
# Openness_Conscientiousness_Ratio    400000
# Risk_Index                          400000
# Class                               400000
# dtype: int64

# %% [markdown]
# # Unique value of the dataset

# %%
display(train_df.nunique())
# Out:
# Gender                                2
# Age                                  43
# openness                              7
# neuroticism                           7
# conscientiousness                     7
# agreeableness                         7
# extraversion                          7
# Total_Trait_Score                    31
# Dominant_Trait                        5
# Trait_Balance                        82
# Age_Group                             5
# Gender_Code                           2
# Openness_Conscientiousness_Ratio     35
# Risk_Index                          124
# Class                               430
# dtype: int64

# %% [markdown]
# # Display the each value of percentage of the dataset

# %%
display(train_df.value_counts(normalize=True))
# Out:
# Gender  Age  openness  neuroticism  conscientiousness  agreeableness  extraversion  Total_Trait_Score  Dominant_Trait     Trait_Balance  Age_Group    Gender_Code  Openness_Conscientiousness_Ratio  Risk_Index  Class
# Female  44   3         7            5                  6              7             28                 neuroticism        1.496663       Mid-age      0.0          0.600000                          3.4         At 44 years old, this female individual shows a dominant trait of neuroticism.          0.00006
#         48   1         4            3                  2              4             14                 neuroticism        1.166190       Mid-age      0.0          0.333333                          1.9         At 48 years old, this female individual shows a dominant trait of neuroticism.          0.00006
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np 
import math

# %% [markdown]
# ### Barplot of the Traits of Gender

# %% [markdown]
# ## Numerical Data

# %%
sns.boxplot(data=train_df, x='Gender', y='extraversion')
plt.title('Extraversion by Gender')
plt.show()

# %% [markdown]
# ### Trait Distribution

# %%
traits = ['conscientiousness', 'agreeableness', 'extraversion']

for trait in traits:
    plt.figure(figsize=(6, 4))
    sns.histplot(data=train_df, x=trait, kde=True, bins=7)
    plt.title(f'Distribution of {trait.capitalize()}')
    plt.xlabel(trait.capitalize())
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# ### Countplot of Dominant Trait

# %%
sns.countplot(data=train_df, x='Dominant_Trait', order=train_df['Dominant_Trait'].value_counts().index)
plt.title('Frequency of Dominant Traits')
plt.xlabel('Dominant Trait')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Pairplot to See Trait Interactions

# %%
traits = ['openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism']
sns.pairplot(train_df[traits+['Gender']], hue='Gender')
plt.suptitle('Trait Interactions by Gender', y=1.02)
plt.show()

# %% [markdown]
# ### Bar Plot of Average Trait Scores by Age Group

# %%
avg_traits = train_df.groupby('Age_Group')[traits].mean().reset_index()
avg_traits.plot(x='Age_Group', kind='bar', figsize=(8,5))
plt.title('Average Trait Scores by Age Group')
plt.ylabel('Average Score')
plt.xticks(rotation=0)
plt.legend(title='Trait')
plt.show()

# %% [markdown]
# ### Distribution od the Dominat Count

# %%
dominant_counts = train_df['Dominant_Trait'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(dominant_counts, labels=dominant_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Dominant Personality Trait Distribution')
plt.axis('equal')  
plt.show()

# %% [markdown]
# ### Group of the gender distribution

# %%
age_group = train_df['Age_Group'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(age_group, labels=age_group.index, autopct='%1.1f%%', startangle=140)
plt.title('Group of the Age Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Boxplot

# %%
num_cols = ['Age', 'openness', 'neuroticism', 'conscientiousness',
            'agreeableness', 'extraversion', 'Total_Trait_Score',
            'Trait_Balance', 'Openness_Conscientiousness_Ratio', 'Risk_Index']
def my_boxplot(data, column, ax):
    sns.boxplot(y=data[column], ax=ax)
    ax.set_title(column)

import math  # Math function is used for the mathematical formulas

def plot_charts(data, plot_func, size=(2, 4), n_col=4):
    n = data.shape[1]
    n_row = math.ceil(n / n_col)
    fig, axes = plt.subplots(n_row, n_col, figsize=(size[0]*n_col, size[1]*n_row))
    axes = axes.flatten()

    for i, col in enumerate(data.columns):
        plot_func(data, col, axes[i])

    for j in range(i+1, len(axes)):
        fig.delaxes(axes[j])  # remove unused axes

    plt.tight_layout()
    plt.show()
plot_charts(train_df[num_cols], my_boxplot, size=(2, 4), n_col=4)

# %% [markdown]
# ### Correlation of the dataset

# %%
numeric_df = train_df.select_dtypes(include=[np.number])

# Dynamic heatmap size based on number of numeric columns
n_numeric_cols = len(numeric_df.columns)
heatmap_size = (n_numeric_cols * 1.2, n_numeric_cols * 1.2)

# Create the heatmap
plt.figure(figsize=heatmap_size)
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f", square=True, linewidths=0.5)
plt.title('Correlation Heatmap of Numeric Features')
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
train_df['Gender'] = le.fit_transform(train_df['Gender'])  # 'Male' = 1, 'Female' = 0
train_df['Dominant_Trait'] = le.fit_transform(train_df['Dominant_Trait'])  # if it's the target

# %% [markdown]
# ## Feature Transformation

# %%
train_df = train_df.apply(LabelEncoder().fit_transform)

# %%
train_df.head()
# Out:
#    Gender  Age  openness  neuroticism  conscientiousness  agreeableness  \
# 0       1    8         3            6                  1              4
# 1       0   35         3            1                  4              4
# 2       0    5         3            5                  6              5
# 3       0   23         4            1                  0              3
# 4       1   25         6            0                  4              5
#
#    extraversion  Total_Trait_Score  Dominant_Trait  Trait_Balance  Age_Group  \
# 0             1                 15               3             42          4
# 1             5                 17               2             23          2
# 2             0                 19               1             51          4
# 3             5                 13               2             41          1
# 4             1                 16               4             61          1
#
#    Gender_Code  Openness_Conscientiousness_Ratio  Risk_Index  Class
# ...

# %% [markdown]
# # Models

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import classification_report,accuracy_score
from sklearn import tree
from xgboost import XGBClassifier
import matplotlib.pyplot as plt 
import numpy as np
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Random Forest

# %%
x = train_df.drop('Age_Group',axis=1)
y = train_df['Age_Group']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
## Random Foresst

model = RandomForestClassifier(
    n_estimators=100,
    random_state=42)
model = RandomForestClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test) 
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
# Step 7: Save the trained model
import pickle
with open('random_forest_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
pip install streamlit pyngrok
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%writefile Prediction.py
import streamlit as st
import pandas as pd
import numpy as np
import pickle

# Load model
with open('random_forest_model.pkl', 'rb') as file:       # read binary(rb)  and write binary(wb)
    model = pickle.load(file)

# Prediction descriptions (customize as needed)
personality_descriptions = {
    0: {
        "type": "Introvert",
        "description": "You are reflective, observant, and prefer solitude or quiet environments. You find energy in your inner world and enjoy meaningful one-on-one conversations. While not shy, you are introspective and thoughtful in your interactions.",
        "compliment": "You're deep, thoughtful, and wonderfully calm. ✨"
    },
    1: {
        "type": "Extrovert",
        "description": "You are outgoing, energetic, and enjoy being around people. Social interaction fuels your energy, and you are typically enthusiastic, talkative, and action-oriented. You're the life of the party!",
        "compliment": "You're full of life and light up every room! 🌟"
    },
    2: {
        "type": "Ambivert",
        "description": "You have a balanced personality with traits of both introverts and extroverts. You adapt to situations easily — enjoying social time as well as time alone. You are flexible, intuitive, and emotionally intelligent.",
        "compliment": "You’re versatile, balanced, and beautifully unique. 🌈"
    },
    3: {
        "type": "Analyst",
        "description": "You are logical, analytical, and love solving problems. You rely on reason more than emotion and often think strategically. You seek depth, patterns, and clarity in everything you do.",
        "compliment": "You're smart, sharp, and an insightful thinker. 🧠"
    },
    4: {
        "type": "Diplomat",
        "description": "You are empathetic and cooperative. You value harmony, relationships, and emotional connection. You are intuitive and often the peacemaker in social groups, creating warmth and understanding wherever you go.",
        "compliment": "You're kind-hearted, wise, and deeply appreciated. 💖"
    }
    # Add more if needed based on your model's output
}

# App layout
st.title("🧠 ML Based Personality Profiling")
st.markdown("Fill in your traits to get your predicted personality type and a personalized message!")

# Inputs
gender_code = st.selectbox("Gender Code", [0, 1], format_func=lambda x: "Male" if x == 0 else "Female")
age = st.number_input("Enter your Age", min_value=10, max_value=100, value=25)

openness = st.number_input("Openness (0-10)", min_value=0.0, max_value=10.0, value=5.0)
conscientiousness = st.number_input("Conscientiousness (0-10)", min_value=0.0, max_value=10.0, value=5.0)
extraversion = st.number_input("Extraversion (0-10)", min_value=0.0, max_value=10.0, value=5.0)
agreeableness = st.number_input("Agreeableness (0-10)", min_value=0.0, max_value=10.0, value=5.0)
neuroticism = st.number_input("Neuroticism (0-10)", min_value=0.0, max_value=10.0, value=5.0)

# Derived features (scaled for 0–10)
openness_conscientiousness_ratio = openness / conscientiousness if conscientiousness != 0 else 0
risk_index = (neuroticism + (10 - agreeableness) + (10 - conscientiousness)) / 3
total_trait_score = openness + conscientiousness + extraversion + agreeableness + neuroticism
trait_balance = abs(openness - neuroticism)

# Build DataFrame for prediction
input_df = pd.DataFrame([{
    "Age": age,
    "Gender_Code": gender_code,
    "Openness": openness,
    "Conscientiousness": conscientiousness,
    "Extraversion": extraversion,
    "Agreeableness": agreeableness,
    "Neuroticism": neuroticism,
    "Openness_Conscientiousness_Ratio": openness_conscientiousness_ratio,
    "Risk_Index": risk_index,
    "Total_Trait_Score": total_trait_score,
    "Trait_Balance": trait_balance,
}])

# Align with model features
try:
    model_features = model.feature_names_in_
except AttributeError:
    model_features = input_df.columns.tolist()

for col in model_features:
    if col not in input_df.columns:
        input_df[col] = 0

input_df = input_df[model_features]

# Predict button
if st.button("🔮 Predict My Personality"):
    try:
        prediction = model.predict(input_df)[0]
        result = personality_descriptions.get(prediction, {
            "type": f"Unknown ({prediction})",
            "description": "No description available for this type.",
            "compliment": "You are unique in your own way! ✨"
        })

        # Build result table
        result_df = pd.DataFrame({
            "Your Age": [age],
            "Predicted Personality": [result["type"]],
            "Character Description": [result["description"]],
            "Final Note": [result["compliment"]]
        })

        st.success("🎉 Prediction Complete!")
        st.markdown("### 🧾 Prediction Summary")
        st.table(result_df)

    except Exception as e:
        st.error(f"❌ Prediction failed: {e}")
# Out:
# Overwriting Prediction.py
